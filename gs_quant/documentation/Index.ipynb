# %% [markdown]
# # Index

# %% [markdown]
# - **CSA** -
#       [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/16_change_discount_curve.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/16_change_discount_curve.ipynb) cell 3
#       [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/20_fix_float_legs_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/20_fix_float_legs_price.ipynb) cell 3
# - **Contexts - Historical Pricing Context** -
#                                         [02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/2_cdindex_option_xover_payer_spread.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/2_cdindex_option_xover_payer_spread.ipynb) cell 5
# - **Contexts - HistoricalPricingContext** -
#                                       [02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/4_calc_eq_option_price_and_risk_historically.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/4_calc_eq_option_price_and_risk_historically.ipynb) cell 3
# - **Contexts - Market Data Based Shock Scenario** -
#                                               [02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/5_calc_eq_option_portfolio_greeks.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/5_calc_eq_option_portfolio_greeks.ipynb) cell 2
# - **Contexts - PricingContext** -
#                             [02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/3_calc_eq_option_price_and_risk_in_pricing_context.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/3_calc_eq_option_price_and_risk_in_pricing_context.ipynb) cell 3
# - **Enums - BusinessDayConvention** -
#                                 [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb) cell 16
# - **Enums - Currency** -
#                    [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb) cell 7
# - **Enums - DayCountFraction** -
#                            [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb) cell 15
# - **Enums - Knock In / Knock Out** -
#                                [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/7_fx_knockout_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/7_fx_knockout_trade_construction.ipynb) cell 4
# - **Enums - OptionSettlementMethod** -
#                                  [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/7_fx_knockout_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/7_fx_knockout_trade_construction.ipynb) cell 12
# - **Enums - PayReceive** -
#                      [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb) cell 5
#                      [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/9_swaption_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/9_swaption_trade_construction.ipynb) cell 4
#                      [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/9_swaption_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/9_swaption_trade_construction.ipynb) cell 9
# - **Enums - SwapClearingHouse** -
#                             [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb) cell 19
# - **Enums - UnderlyierType** -
#                          [02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/1_calc_eq_option_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/1_calc_eq_option_price.ipynb) cell 5
# - **Enums - Upper barrier / Lower barrier** -
#                                         [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/7_fx_knockout_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/7_fx_knockout_trade_construction.ipynb) cell 5
# - **Instrument - CDIndex** -
#                        [02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/4_cdindex_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/4_cdindex_price.ipynb)
# - **Instrument - CDIndexOption** -
#                              [02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/1_cdindex_option_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/1_cdindex_option_price.ipynb)
# - **Instrument - Cloning** -
#                        [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/17_calc_xccy_swap_cashflows.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/17_calc_xccy_swap_cashflows.ipynb) cell 8
# - **Instrument - Credit Index Rolling** -
#                                     [02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/5_cdindex_roll_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/5_cdindex_roll_price.ipynb)
# - **Instrument - Credit Payer Spread** -
#                                    [02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/2_cdindex_option_xover_payer_spread.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/2_cdindex_option_xover_payer_spread.ipynb)
# - **Instrument - EqOption** -
#                         [02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/1_calc_eq_option_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/1_calc_eq_option_price.ipynb)
# - **Instrument - FX DNT** -
#                       [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/8_fx_double_touch_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/8_fx_double_touch_trade_construction.ipynb)
# - **Instrument - FXBinary** -
#                         [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/4_fx_binary_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/4_fx_binary_trade_construction.ipynb)
# - **Instrument - FXDoubleOneTouch** -
#                                 [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/8_fx_double_touch_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/8_fx_double_touch_trade_construction.ipynb)
# - **Instrument - FXForward** -
#                          [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/1_fx_fwd_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/1_fx_fwd_trade_construction.ipynb)
# - **Instrument - FXKnockout** -
#                           [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/7_fx_knockout_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/7_fx_knockout_trade_construction.ipynb)
# - **Instrument - FXVolatilitySwap** -
#                                 [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/3_fx_vol_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/3_fx_vol_swap_trade_construction.ipynb)
# - **Instrument - IRAssetSwapFxdFlt** -
#                                  [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/21_asset_swap_definition.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/21_asset_swap_definition.ipynb) cell 2
# - **Instrument - IRCMSSpreadOption** -
#                                  [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/15_spread_option_grid_pricing.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/15_spread_option_grid_pricing.ipynb) cell 2
# - **Instrument - IRFixedLeg** -
#                           [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/20_fix_float_legs_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/20_fix_float_legs_price.ipynb) cell 2
# - **Instrument - IRFloatLeg** -
#                           [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/20_fix_float_legs_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/20_fix_float_legs_price.ipynb) cell 2
# - **Instrument - Rates Midcurve Swaption** -
#                                        [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/11_midcurve_swaption_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/11_midcurve_swaption_price.ipynb)
# - **Instrument - Resolve** -
#                        [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/6_calc_swap_price_historically.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/6_calc_swap_price_historically.ipynb) cell 2
# - **Instrument - Solving - DNT strikes** -
#                                      [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/8_fx_double_touch_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/8_fx_double_touch_trade_construction.ipynb) cell 11
# - **Instrument - Solving - EqOption strike solving** -
#                                                  [02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/1_calc_eq_option_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/1_calc_eq_option_price.ipynb) cell 6
# - **Instrument - Solving - FX Binary strike solving** -
#                                                   [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/4_fx_binary_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/4_fx_binary_trade_construction.ipynb) cell 5
# - **Instrument - Solving - Size one trade by the risk of another trade** -
#                                                                      [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/19_solve_delta.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/19_solve_delta.ipynb) cell 3
# - **Instrument - Solving - Solving FXVolSwap strike vol** -
#                                                       [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/3_fx_vol_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/3_fx_vol_swap_trade_construction.ipynb) cell 10
# - **Instrument - Solving across multiple instruments** -
#                                                    [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/18_solve_present_value.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/18_solve_present_value.ipynb) cell 3
# - **Instrument - XCcy Swap** -
#                          [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/13_calc_xccy_swap_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/13_calc_xccy_swap_price.ipynb)
# - **Instrument - XccySwap** -
#                         [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/17_calc_xccy_swap_cashflows.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/17_calc_xccy_swap_cashflows.ipynb) cell 2
# - **Instrument - create from dictionary** -
#                                       [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb) cell 23
# - **Instrument Properties** -
#                         [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/1_view-trade-properties.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/1_view-trade-properties.ipynb) cell 2
#                         [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/1_view-trade-properties.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/1_view-trade-properties.ipynb) cell 4
#                         [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/2_get-a-property.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/2_get-a-property.ipynb) cell 3
#                         [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/2_get-a-property.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/2_get-a-property.ipynb) cell 4
#                         [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/3_set-a-property.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/3_set-a-property.ipynb) cell 3
#                         [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/4_enum-property.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/4_enum-property.ipynb) cell 3
#                         [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/4_enum-property.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/4_enum-property.ipynb) cell 5
# - **Instrument Properties - Credit Index Families** -
#                                                 [02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/4_cdindex_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/4_cdindex_price.ipynb) cell 2
# - **Instrument Properties - FX Option Premium** -
#                                             [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/8_fx_double_touch_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/8_fx_double_touch_trade_construction.ipynb) cell 13
# - **Instrument Properties - Fixing Frequency** -
#                                            [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/3_fx_vol_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/3_fx_vol_swap_trade_construction.ipynb) cell 6
# - **Instrument Properties - Fixing Source** -
#                                         [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/3_fx_vol_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/3_fx_vol_swap_trade_construction.ipynb) cell 8
# - **Instrument Properties - Solving - IRSwaption strike** -
#                                                       [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/9_swaption_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/9_swaption_trade_construction.ipynb) cell 6
# - **Instrument Properties - credit underlying index** -
#                                                   [02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/1_cdindex_option_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/1_cdindex_option_price.ipynb) cell 3
# - **Instrument Solving - FXKO Strike Solving** -
#                                            [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/7_fx_knockout_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/7_fx_knockout_trade_construction.ipynb) cell 11
# - **Market Data - Overwriting** -
#                             [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/6_market-data.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/6_market-data.ipynb) cell 11
#                             [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/6_market-data.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/6_market-data.ipynb) cell 13
# - **Market Data - Retrieval** -
#                           [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/6_market-data.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/6_market-data.ipynb) cell 4
#                           [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/6_market-data.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/6_market-data.ipynb) cell 6
#                           [02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/6_market-data.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/00_instrument_basics/6_market-data.ipynb) cell 8
# - **Market Data - location** -
#                          [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/5_calc_swap_price_in_pricing_context.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/5_calc_swap_price_in_pricing_context.ipynb) cell 3
# - **Metrics** -
#           [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/4_calc_swap_risk_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/4_calc_swap_risk_measures.ipynb) cell 3
#           [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/7_calc_swap_risks_in_pricing_context.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/7_calc_swap_risks_in_pricing_context.ipynb) cell 3
# - **Metrics - Black-Scholes Delta** -
#                                 [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/9_fx_delta_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/9_fx_delta_measures.ipynb) cell 6
# - **Metrics - Cashflows** -
#                       [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/12_swap_future_cashflows.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/12_swap_future_cashflows.ipynb) cell 3
#                       [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/17_calc_xccy_swap_cashflows.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/17_calc_xccy_swap_cashflows.ipynb) cell 4
# - **Metrics - Credit Greeks** -
#                           [02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/3_cdindex_option_risks.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/3_cdindex_option_risks.ipynb) cell 3
# - **Metrics - Credit metrics** -
#                            [02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/1_cdindex_option_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/1_cdindex_option_price.ipynb) cell 7
# - **Metrics - Delta as Notional of fwd** -
#                                      [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/9_fx_delta_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/9_fx_delta_measures.ipynb) cell 10
# - **Metrics - Equity Greeks** -
#                           [02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/5_calc_eq_option_portfolio_greeks.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/5_calc_eq_option_portfolio_greeks.ipynb) cell 6
# - **Metrics - Equity Risks** -
#                          [02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/2_calc_eq_option_risk_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/2_calc_eq_option_risk_measures.ipynb) cell 4
# - **Metrics - FX Delta Measures** -
#                               [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/9_fx_delta_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/9_fx_delta_measures.ipynb)
# - **Metrics - FXAnnualImpliedVol, Metrics - FXAnnualATMImpliedVol** -
#                                                                 [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/5_calc_option_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/5_calc_option_measures.ipynb) cell 2
# - **Metrics - FXDelta** -
#                     [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/9_fx_delta_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/9_fx_delta_measures.ipynb) cell 8
# - **Metrics - FXFwd** -
#                   [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/4_fx_binary_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/4_fx_binary_trade_construction.ipynb) cell 7
# - **Metrics - FXSpot** -
#                    [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/4_fx_binary_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/4_fx_binary_trade_construction.ipynb) cell 5
# - **Metrics - FairVolStrike** -
#                           [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/3_fx_vol_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/3_fx_vol_swap_trade_construction.ipynb) cell 15
# - **Metrics - Price** -
#                   [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/3_calc_swap_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/3_calc_swap_price.ipynb) cell 3
# - **Metrics - XCcy** -
#                  [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/14_calc_xccy_swap_risk_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/14_calc_xccy_swap_risk_measures.ipynb) cell 3
# - **Metrics - aggregation level** -
#                               [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/7_calc_swap_risks_in_pricing_context.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/7_calc_swap_risks_in_pricing_context.ipynb) cell 3
# - **Metrics - aggregation_level** -
#                               [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/8_calc_swap_risk_historically.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/8_calc_swap_risk_historically.ipynb) cell 3
# - **Metrics - parameterized currency** -
#                                    [02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/2_calc_eq_option_risk_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/2_calc_eq_option_risk_measures.ipynb) cell 6
# - **Portfolio - Nested Portfolios** -
#                                 [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/15_spread_option_grid_pricing.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/15_spread_option_grid_pricing.ipynb) cell 2
# - **Portfolios** -
#              [02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/5_calc_eq_option_portfolio_greeks.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/5_calc_eq_option_portfolio_greeks.ipynb) cell 4
# - **Properties - Solving - Swap fixed rate** -
#                                          [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb) cell 9
# - **Properties - floating_rate_option** -
#                                     [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/2_swap_trade_construction.ipynb) cell 11
# - **Results** -
#           [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/4_calc_swap_risk_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/4_calc_swap_risk_measures.ipynb) cell 4
#           [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/4_calc_swap_risk_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/4_calc_swap_risk_measures.ipynb) cell 5
# - **Results - Multiple Measures** -
#                               [02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/5_calc_option_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/02_fx/5_calc_option_measures.ipynb) cell 2
# - **Results - Retrieve Specific Measure** -
#                                       [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/7_calc_swap_risks_in_pricing_context.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/7_calc_swap_risks_in_pricing_context.ipynb) cell 5
# - **Results - aggregating** -
#                         [02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/5_cdindex_roll_price.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/04_credit/5_cdindex_roll_price.ipynb) cell 8
# - **Results - historical results** -
#                                [02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/8_calc_swap_risk_historically.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/01_rates/8_calc_swap_risk_historically.ipynb) cell 5
# - **Results - slice multi risk results** -
#                                      [02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/2_calc_eq_option_risk_measures.ipynb](02_pricing_and_risk/00_instruments_and_measures/examples/03_eq/2_calc_eq_option_risk_measures.ipynb) cell 5
